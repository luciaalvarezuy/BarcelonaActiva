# %% [markdown]
# #### Ejercicio 1
# Resume gráficamente el data set DelayedFlights.csv
#
# https://www.kaggle.com/datasets/giovamata/airlinedelaycauses
#
#
# Descripcion de las variables
# https://www.kaggle.com/code/adveros/flight-delay-eda-exploratory-data-analysis

# %%
import pandas
filename = 'DelayedFlights.csv'
data = pandas.read_csv(filename, header=0)

print(data.columns.values)
# Out:
# ['Unnamed: 0' 'Year' 'Month' 'DayofMonth' 'DayOfWeek' 'DepTime'
#  'CRSDepTime' 'ArrTime' 'CRSArrTime' 'UniqueCarrier' 'FlightNum' 'TailNum'
#  'ActualElapsedTime' 'CRSElapsedTime' 'AirTime' 'ArrDelay' 'DepDelay'
#  'Origin' 'Dest' 'Distance' 'TaxiIn' 'TaxiOut' 'Cancelled'
#  'CancellationCode' 'Diverted' 'CarrierDelay' 'WeatherDelay' 'NASDelay'
#  'SecurityDelay' 'LateAircraftDelay']

# %% [markdown]
# Crea al menos una visualización por:
#
# ##  Una variable categórica (UniqueCarrier)

# %% [markdown]
# ##  Una variable numérica (ArrDelay)

# %% [markdown]
# ##  Una variable numérica y una categórica (ArrDelay y  UniqueCarrier)

# %%
# Out:
# <AxesSubplot:xlabel='UniqueCarrier', ylabel='ArrDelay'>

# %% [markdown]
# ## Dos variables numéricas (ArrDelay y DepDelay)
#
# #### Variable 1
# ArrDelay arrival delay, in minutes: A flight is counted as "on time" if it operated less than 15 minutes later the scheduled time shown in the carriers' Computerized Reservations Systems (CRS).
#
# #### Variable 2
# DepDelay departure delay, in minutes

# %%
# En este caso son dos variables numericas ordenadsa?

import numpy as np
import matplotlib.pyplot as plt

plt.fill_between(data.DepDelay, data.ArrDelay)
plot.show()

# %% [markdown]
# ## Tres variables (ArrDelay, DepDelay y UniqueCarrier)
#
#
# #### Variable 1
# ArrDelay arrival delay, in minutes: A flight is counted as "on time" if it operated less than 15 minutes later the scheduled time shown in the carriers' Computerized Reservations Systems (CRS). (cuanti ordenada)
#
# #### Variable 2
# DepDelay departure delay, in minutes (cuanti ordenada)
#
# #### Variable 3
# UniqueCarrier unique carrier code (categorica)
#
# # DUDA
# Hay orden o no?

# %%
data.UniqueCarrier.describe()

print(type(data.UniqueCarrier))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Más de tres variables (ArrDelay, DepDelay, AirTime y UniqueCarrier).
#
# #### Variable 1
# ArrDelay arrival delay, in minutes: A flight is counted as "on time" if it operated less than 15 minutes later the scheduled time shown in the carriers' Computerized Reservations Systems (CRS). (cuanti ordenada)
#
# #### Variable 2
# DepDelay departure delay, in minutes (cuanti ordenada)
#
# #### Variable 3
# AirTime in minutes (Cuanti ordenada)
#
# #### Variable 4
# UniqueCarrier unique carrier code (categorica)
