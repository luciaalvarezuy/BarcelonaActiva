# %% [markdown]
# ### Actividad 1:

# %%
# Crear una lista que agrupe los meses  del año en trimestres (1T: Enero, Febrero y Marzo, 2T: Abril, Mayo, Junio...)

#Crear las listas con los trimestres
Trimestre01 = ["Enero", "Febrero", "Marzo"]
Trimestre2 = ["Abril", "Mayo", "Junio"]
Trimestre3 = ["Julio", "Agosto", "Septiembre"]
Trimestre4 = ["Octubre", "Noviembre", "Diciembre"]

#Crear una lista vacia para luego incorporarle las listas con los trimestres
list1 = []
list1.append(Trimestre01)
list1.append(Trimestre2)
list1.append(Trimestre3)
list1.append(Trimestre4)

#Imprimir la lista
print(list1)
# Out:
# [['Enero', 'Febrero', 'Marzo'], ['Abril', 'Mayo', 'Junio'], ['Julio', 'Agosto', 'Septiembre'], ['Octubre', 'Noviembre', 'Diciembre']]

# %% [markdown]
# ### Actividad 2:

# %%
#Crea un código que te permita acceder a:
#El segundo mes del primer trimestre

print(list1[0][1])
# Out:
# Febrero

# %%
# Crea un código que te permita acceder a Los meses del primer trimestre
print(list1[0])
# Out:
# ['Enero', 'Febrero', 'Marzo']

# %%
# Crea un código que te permita acceder a: Septiembre y octubre
print([list1[2][2]],[list1[3][0]])
# Out:
# ['Septiembre'] ['Octubre']

# %% [markdown]
# ### Actividad 3:

# %%
# Crea una lista con números desordenados  y responde a las siguientes preguntas: ¿Cuántos números hay?

# Crear lista
list2 = [2, 5, 3, 6, 2, 0, 8, 9, 3 , 2 , 3]

# Código para responder a la pregunta
x = len(list2)

print ("En la lista tenemos", x , "elementos")
# Out:
# En la lista tenemos 11 elementos

# %% [markdown]
# Cuántas veces aparece el número 3

# %%
# Cuántas veces aparece el número 3
y = list2.count(3)

print("El número 3 aparece ", y , " en la lista creada")
# Out:
# El número 3 aparece  3  en la lista creada

# %%
# ¿Cuántas veces aparecen los números 3 y 4?

aparece3 = list2.count(3)
aparece4 = list2.count(4)


print("El número 3 aparece ", aparece3 , " veces en la lista. El número 4 aparece ", aparece4, " veces.")
# Out:
# El número 3 aparece  3  veces en la lista. El número 4 aparece  0  veces.

# %%
# ¿Cuál es el mayor número?
max_value = max(list2)
print('El valor máximo de la lista es: ', max_value)
# Out:
# El valor máximo de la lista es:  9

# %%
#¿Cuáles son los 3 números más pequeños?

list2.sort()
 
print("Los tres números más pequeños son:", list2[0], ","  , list2[1], "y" , list2[2])
# Out:
# Los tres números más pequeños son: 0 , 2 y 2

# %%
# ¿Cuál es el rango de esa lista?
def my_function(x , y):
    rango = x - y
    print("El rango de la lista es de ", rango)

my_function(max(list2), min(list2))
# Out:
# El rango de la lista es de  9

# %%
compra = { "Manzanas" : {"Qty": 5, '€': 0.42}, "Peras" : {"Qty": 3, '€': 0.66} }
  
# Añade alguna fruta más
compra["Naranjas"] = {"Qty": 6, '€': 1.42}
print("El nuevo diccionario es: ",compra)

#¿Cuánto han costado las peras en total?
def cuanto_costo(x , y):
    gasto = x*y
    print("Las peras costaron €", gasto)

cuanto_costo(compra['Peras']['Qty'],  compra['Peras']['€'])

#¿Cuántas frutas hemos comprado en total?
def cantidad_frutas(x, y, z):
    gasto = x+y+z
    print("En total se compraron ", gasto , " frutas")

cantidad_frutas(compra['Manzanas']['Qty'], compra['Peras']['Qty'], compra['Naranjas']['Qty'])

#¿Cuál es la fruta más cara?
from collections import OrderedDict 
from operator import getitem 

#Ordenar el diccionario en función del precio de las frutas
res = OrderedDict(sorted(compra.items(), 
       key = lambda x: getitem(x[1], '€'))) 
  
#Evaluar si el diccionario se oredno correctamente
#print("El diccionario ordenado es : " + str(res))

# Suprimir par clave/valor por el final y  asignar tupla con datos:
verFrutaMasCara = res.popitem()

# Muestra únicamente lo que necesitamos:
print ("La fruta más cara son las: ", verFrutaMasCara[0])
# Out:
# El nuevo diccionario es:  {'Manzanas': {'Qty': 5, '€': 0.42}, 'Peras': {'Qty': 3, '€': 0.66}, 'Naranjas': {'Qty': 6, '€': 1.42}}
# Las peras costaron € 1.98
# En total se compraron  14  frutas
# La fruta más cara son las:  Naranjas

# %% [markdown]
# ### Ejercicio 3 de S03 T01: Visualización gráfica de un dataset:
# #### Integra las visualizaciones gráficas, en la tarea 5, del Sprint 2.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


img = mpimg.imread('fig1.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('fig2.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('fig3.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('fig4.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('fig5.png')
imgplot = plt.imshow(img)
plt.show()

# %%
img = mpimg.imread('fig6.png')
imgplot = plt.imshow(img)
plt.show()
