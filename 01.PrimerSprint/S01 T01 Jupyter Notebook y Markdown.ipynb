# %% [markdown]
# A continuación, se realizará una **suma**

# %%
x= 5
y= 2

result = 'El resultado de 1 + 2 es: ' + str( x + y)

result
# Out:
# 'El resultado de 1 + 2 es: 7'

# %% [markdown]
# <font color='green'> Este es el *primer ejercicio* de los tantos del curso</font>
#
#
# <font color='red'>A continuación, vamos a adjuntar una imágen
# </font>
#
#
# ![Python.jpg](attachment:Python.jpg)

# %% [markdown]
# Vamos a probar como funciona la **extensión ***Nbextensions
#
# # This is a super big title
# ## This is a big title
# ### This is a medium title
# #### This is a small title

# %%
 jupyter nbconvert --to html notebook.ipynb
# Out:
#   File "C:\Users\LUCAAL~1\AppData\Local\Temp/ipykernel_17972/528973907.py", line 1
#     jupyter nbconvert --to html notebook.ipynb
#             ^
# SyntaxError: invalid syntax
