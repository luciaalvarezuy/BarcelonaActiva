# %%
import pandas as pd
import re
#import numpy as np


# https://www.analyticslane.com/2020/10/19/separar-texto-en-columnas-con-pandas-en-python/

#Para vizualizar todo el contenido del documento
pd.set_option('display.max_colwidth', None)

df = pd.read_csv('C:/Users/Lucía Alvarez/OneDrive - psico.edu.uy/00 Barcelona activa/Web_access_log-akumenius.com.txt', 
                 delimiter = "\t", header=None)
df.columns =['Primera_variable']


df.describe()
# Out:
#                                                                                                                        Primera_variable
# count                                                                                                                            261873
# unique                                                                                                                           257310
# top     localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# freq                                                                                                                                 22

# %%
####REVISAR BIEN PORQUE DEJO ESTO!!!
#En primer lugar, estamos creando una expresión regular 

patro=("[^\"]*")


#entoncess estamos pasando cada fila de la columna específica a re.findall() la función de extracción de la puntuacion y luego la asignación de puntuacion que extraen en una nueva columna en una trama de datos.

columnas_de_Tabla=df["Primera_variable"].apply(lambda x: re.findall(patro,x))


#df["web"]=columnas_de_Tabla.map(lambda x: x[0].split(' ')[0])

#df.loc[15:25,:]

# %%
Nueva_variable = df["Primera_variable"].str.split('- -', expand=True)

df=df.assign(Pagina_WEB=Nueva_variable[0])  #, RESTO_DE_DATOS=Nueva_variable[1]
#lo que sigue de la linea anterior lo borre
df
# Out:
#                                                                                                                                                                     Primera_variable  \
# 0                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 1                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 2                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 3                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
#Borrar la variable original (luego de verificar que todo esta ok)
#df = df.drop("Primera_variable", axis=1)

# %%
new = df['Pagina_WEB'].str.split(" ", n = 1, expand = True) 
  
df["Página WEB"]= new[0] 
  
df["IP"]= new[1] 
  
df
# Out:
#                                                                                                                                                                     Primera_variable  \
# 0                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 1                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 2                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 3                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
#Eliminar la variable que acabo de separar
df.drop(columns =["Pagina_WEB"], inplace = True) 
df
# Out:
#                                                                                                                                                                     Primera_variable  \
# 0                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 1                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 2                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 3                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
patro_data_hora="\d{1,2}/[a-zA-Z]{3}/\d{2,4}:\d{2}:\d{2}:\d{2}\s(\+|\-)\d{4}"

df["data_hora"]=columnes.map(lambda columna: re.search(patro_data_hora,columna[0]).group())


df
# Out:
#                                                                                                                                                                     Primera_variable  \
# 0                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 1                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 2                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 3                                                    localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
df["get"]=columnes.map(lambda columna: columna[2])

df.loc[15:25,:]
# Out:
#                                                                                                                                                                                                                                                                 Primera_variable  \
# 15                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 16                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
df["numeros"]=columnes.map(lambda columna: columna[4] if len(columna)>=5 else "")

df.loc[15:25,:]

#porque pone el mayor a 5?
# Out:
#                                                                                                                                                                                                                                                                 Primera_variable  \
# 15                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 16                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
# Creació d'una nova columna, de nom 'pagina', que enmagatzemarà la pàgina visita
# Aquesta informació está dins la sisena 'columna' de 'columnes'
df["pagina"]=columnes.map(lambda columna: columna[6] if len(columna)>=7 else "")
# Mostrar una desena de registres de 'taula', de la fila 15 a la 25
df.loc[15:25,:]
# Out:
#                                                                                                                                                                                                                                                                 Primera_variable  \
# 15                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 16                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...

# %%
# Creació d'una nova columna, de nom 'navegador', que enmagatzemarà el navegador usat per visitar la pàgina
# Aquesta informació está dins la desena 'columna' de 'columnes'
df["navegador"]=columnes.map(lambda columna: columna[10] if len(columna)>=11 else "")
# Mostrar una desena de registres de 'taula', de la fila 15 a la 25
df.loc[15:25,:]
# Out:
#                                                                                                                                                                                                                                                                 Primera_variable  \
# 15                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 16                                                                                                                                               localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# ...
